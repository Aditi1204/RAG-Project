# %%
import os
from dotenv import load_dotenv

load_dotenv()

if os.environ['OPENAI_API_KEY']:
    print("API key is set")
# Out:
# API key is set

# %%
from langchain_openai import ChatOpenAI

# %%
llm=ChatOpenAI(model_name="gpt-5-nano", temperature=0)

# %%
import os

os.environ["OPENAI_HTTP2"] = "false"
os.environ["HTTPX_DISABLE_HTTP2"] = "1"

# %%
import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path=".env", override=True)
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-5-nano",
    temperature=0
)

print(llm.invoke("What is AI? Answer in one line").content)
# Out:
# AI is the field of computer science that builds systems capable of performing tasks that normally require human intelligence, such as learning, reasoning, and perception.

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Aditi Aryan\Downloads\RAG_Project

# %%
import os
print(os.path.exists(".env"))
# Out:
# True

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# None

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=r"C:\Users\Aditi Aryan\Downloads\RAG_Project\.env", override=True)

print(os.getenv("OPENAI_API_KEY"))
# Out:
# None

# %%
import os
os.chdir(r"C:\Users\Aditi Aryan\Downloads\RAG_Project")

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

import os
print(os.getenv("OPENAI_API_KEY"))
# Out:
# None

# %%
import os
from dotenv import load_dotenv

load_dotenv(
    dotenv_path=r"C:\Users\Aditi Aryan\Downloads\RAG_Project\.env",
    override=True
)

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
print(llm.invoke("What is AI? Answer in one line").content)
# Out:
# AI, or artificial intelligence, is the simulation of human intelligence processes by machines, particularly computer systems, enabling them to perform tasks such as learning, reasoning, and problem-solving.

# %%
import os
from dotenv import load_dotenv

load_dotenv(
    dotenv_path=r"C:\Users\Aditi Aryan\Downloads\RAG_Project\.env",
    override=True
)

print(os.getenv("OPENAI_API_KEY"))  # should print sk-...

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
print(llm.invoke("What is AI? Answer in one line").content)
# Out:
# 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
# AI, or artificial intelligence, is the simulation of human intelligence processes by machines, particularly computer systems, enabling them to perform tasks such as learning, reasoning, and problem-solving.

# %% [markdown]
# # **RAG IMPLEMENTATION WITH OWN TEXT**

# %% [markdown]
# **STEP 1 :PREPARING DOCUMENT FOR YOUR OWN TEXT**

# %%
from langchain_core.documents import Document

## Your text data
my_text = """Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.[1]

High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., language models and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general applications, often without being called AI because once something becomes useful enough and common enough it's not labeled AI anymore."[2][3]

Various subfields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, perception, and support for robotics.[a] To reach these goals, AI researchers have adapted and integrated a wide range of techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.[b] AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields.[4] Some companies, such as OpenAI, Google DeepMind and Meta,[5] aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.
""" 


docs = [Document(page_content=my_text,metadata={"source":"ABC","documentID":"Doc1"})]
docs
# Out:
# [Document(metadata={'source': 'ABC', 'documentID': 'Doc1'}, page_content='Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.[1]\n\nHigh-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., language models and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general applications, often without being called AI because once something becomes useful enough and common enough it\'s not labeled AI anymore."[2][3]\n\nVarious subfields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, perception, and support for robotics.[a] To reach these goals, AI researchers have adapted and integrated a wide range of techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics.[b] AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields.[4] Some companies, such as OpenAI, Google DeepMind and Meta,[5] aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.\n')]

# %% [markdown]
# **STEP 2: Splitting the text into chunks**

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50)

chunks = splitter.split_documents(docs)
chunks
# Out:
# [Document(metadata={'source': 'ABC', 'documentID': 'Doc1'}, page_content='Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.[1]'),
#  Document(metadata={'source': 'ABC', 'documentID': 'Doc1'}, page_content='High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., language models and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general'),
#  Document(metadata={'source': 'ABC', 'documentID': 'Doc1'}, page_content='lot of cutting edge AI has filtered into general applications, often without being called AI because once something becomes useful enough and common enough it\'s not labeled AI anymore."[2][3]'),
#  Document(metadata={'source': 'ABC', 'documentID': 'Doc1'}, page_content='Various subfields of AI research are centered around particular goals and the use of particular tools. The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, perception, and support for robotics.[a] To reach these goals, AI researchers have adapted and integrated a wide range of techniques, including search and mathematical optimization, formal logic, artificial neural networks, and methods based on statistics,'),
#  Document(metadata={'source': 'ABC', 'documentID': 'Doc1'}, page_content='neural networks, and methods based on statistics, operations research, and economics.[b] AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields.[4] Some companies, such as OpenAI, Google DeepMind and Meta,[5] aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.')]

# %% [markdown]
# **STEP 3: Creating Embeddings for the Chunks**

# %%
from langchain_openai import OpenAIEmbeddings

embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# **STEP 4: Create and Store Embeddings in Vector Store**

# %%
from langchain_community.vectorstores import Chroma

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model
)

# %% [markdown]
# **STEP 5: Semantic Search**

# %%
vectorstore.similarity_search("What is AI?", k= 3)
# Out:
# [Document(metadata={'documentID': 'Doc1', 'source': 'ABC'}, page_content='Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.[1]'),
#  Document(metadata={'documentID': 'Doc1', 'source': 'ABC'}, page_content='High-profile applications of AI include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); virtual assistants (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., language models and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general'),
#  Document(metadata={'documentID': 'Doc1', 'source': 'ABC'}, page_content='neural networks, and methods based on statistics, operations research, and economics.[b] AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields.[4] Some companies, such as OpenAI, Google DeepMind and Meta,[5] aim to create artificial general intelligence (AGI) – AI that can complete virtually any cognitive task at least as well as a human.')]

# %% [markdown]
# **Talk to LLM**

# %%
context = vectorstore.similarity_search("What is AI?", k= 3)

# %%
response = llm.invoke(f"What is AI? You can answer using the following context: {context}")
print(response.content)
# Out:
# Artificial intelligence (AI) refers to the capability of computational systems to perform tasks that are typically associated with human intelligence. This includes abilities such as learning, reasoning, problem-solving, perception, and decision-making. AI is a field of research within computer science that focuses on developing methods and software that allow machines to perceive their environment and utilize learning and intelligence to take actions that help them achieve specific goals.
#
# High-profile applications of AI include advanced web search engines like Google Search, recommendation systems used by platforms such as YouTube, Amazon, and Netflix, virtual assistants like Google Assistant, Siri, and Alexa, autonomous vehicles like Waymo, and generative tools for creative tasks, including language models and AI-generated art. Additionally, AI is employed in superhuman play and analysis in strategy games such as chess and Go.
#
# AI encompasses various techniques, including neural networks and methods based on statistics, operations research, and economics. It also draws from other fields such as psychology, linguistics, philosophy, and neuroscience. Some organizations, like OpenAI, Google DeepMind, and Meta, are working towards creating artificial general intelligence (AGI), which aims to enable AI to perform virtually any cognitive task as well as a human.
